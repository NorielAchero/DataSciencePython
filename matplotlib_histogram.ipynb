# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = [1,3,3,3,3,9,9,5,4,4,8,8,8,6,7]

# %%
plt.hist(data)
# Out:
# (array([1., 0., 4., 2., 0., 1., 1., 1., 3., 2.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. , 5.8, 6.6, 7.4, 8.2, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
sample = pd.read_csv('/content/sample_data/california_housing_test.csv')
sample.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
plt.hist(sample['housing_median_age'], bins = 30, color = "blue")
# Out:
# (array([  8.,  40.,  64.,  20.,  52.,  71.,  41.,  98., 184., 100., 152.,
#         124., 113.,  75., 174., 132.,  75., 133., 176., 102., 233., 152.,
#          98.,  56., 107., 102.,  41.,  56.,  37., 184.]),
#  array([ 1. ,  2.7,  4.4,  6.1,  7.8,  9.5, 11.2, 12.9, 14.6, 16.3, 18. ,
#         19.7, 21.4, 23.1, 24.8, 26.5, 28.2, 29.9, 31.6, 33.3, 35. , 36.7,
#         38.4, 40.1, 41.8, 43.5, 45.2, 46.9, 48.6, 50.3, 52. ]),
#  <BarContainer object of 30 artists>)
