# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
one = np.random.randint(1,9,9)
two = np.random.randint(1,9,9)
three = np.random.randint(1,9,9)

data = list([one, two, three])

# %%
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7c2de3bb4fd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7c2de3bb4f10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7c2de3bb5b40>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7c2de3bb60e0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7c2de3bb4040>,
# ...
#  'means': []}

# %%
plt.violinplot(data)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7c2de357faf0>,
# ...
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7c2de357fa90>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7c2de3624850>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7c2de3624c10>}
